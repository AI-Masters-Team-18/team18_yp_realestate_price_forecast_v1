# %%
# OBSOLETE - не используется тк решили перейти к парсингу M2.ru

# %%
# Install pandas if not already installed
import pandas as pd
df = pd.read_csv("./united_filtered.csv", sep=';')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Install pandas if not already installed
#       2 import pandas as pd
# ----> 3 df = pd.read_csv("./united_filtered.csv", sep=';')
#       4 df
#
# File ~/Documents/Мага ИИ/Годовой проект/team18_yp_realestate_price_forecast_v1/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/Мага ИИ/Годовой проект/team18_yp_realestate_price_forecast_v1/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/Мага ИИ/Годовой проект/team18_yp_realestate_price_forecast_v1/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/Мага ИИ/Годовой проект/team18_yp_realestate_price_forecast_v1/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/Мага ИИ/Годовой проект/team18_yp_realestate_price_forecast_v1/venv/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './united_filtered.csv'

# %%
df_filtered = df.drop(['author','author_type','location','deal_type','accommodation_type'],axis=1) #удаляем ненужные столбцы, оставляем url для парсинга
df_filtered = df_filtered.drop_duplicates() #очищаем от дубликатов
df_filtered
# Out:
#                                             url  floor  floors_count  \
# 0      https://www.cian.ru/sale/flat/306341805/      5            12
# 1      https://www.cian.ru/sale/flat/297733877/     80            85
# 2      https://www.cian.ru/sale/flat/306541543/     18            21
# 3      https://www.cian.ru/sale/flat/293126875/     21            23
# 4      https://www.cian.ru/sale/flat/303408628/      5            14
# ...                                         ...    ...           ...
# 88938  https://www.cian.ru/sale/flat/304959700/     11            33
# 88942  https://www.cian.ru/sale/flat/307447309/      9            43
# 88944  https://www.cian.ru/sale/flat/306283234/      7            10
# 88945  https://www.cian.ru/sale/flat/304957475/      8            33
# 88946  https://www.cian.ru/sale/flat/306237354/     10            16
#
#        rooms_count  total_meters        price              district  \
# 0                4         184.7  460790000.0             Хамовники
# 1                4         294.6  412440000.0           Пресненский
# 2                4         234.3  328184010.0           Пресненский
# 3                4         244.1   78000000.0           Хорошевский
# 4                4         198.4  557450000.0              Якиманка
# ...            ...           ...          ...                   ...
# 88938            1          33.4   10228000.0               Ховрино
# 88942            1          33.5   13300000.0  Покровское-Стрешнево
# 88944            1          33.3    9500000.0                   NaN
# 88945            1          33.2   10065000.0               Ховрино
# 88946            1          33.2    9900000.0        Молжаниновский
#
#                                                   street house_number  \
# 0                                 Фрунзенская набережная           30
# 1      Московский международный деловой центр Москва-...          NaN
# 2                                              Костикова          4к1
# 3                                           Гризодубовой            2
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 88938                                          Клинская          2Ак7
# 88942                                Строительный проезд          9С9
# 88944                                                NaN          2.4
# 88945                                          Клинская          2Ак7
# 88946                                        Северный ао           к3
#
#            underground    residential_complex
# 0          Фрунзенская    Клубный город-парк
# 1        Деловой центр                    NaN
# 2      Улица 1905 года                  Lucky
# 3                 ЦСКА             Гранд-парк
# 4              Полянка        Лаврушинский ЖК
# ...                ...                    ...
# 88938       Грачёвская  мой адрес На Клинской
# 88942      Трикотажная             Sky Garden
# 88944         Потапово       Дзен-кварталы ЖК
# 88945       Грачёвская  мой адрес На Клинской
# 88946   Новоподрезково         Молжаниново ЖК
#
# [72761 rows x 11 columns]

# %%
from parse_detailed_cian_page import parse_page

# %%
from parse_detailed_cian_page import parse_page
from tqdm.notebook import tqdm
import os
# ранее тут реализовывали вызов парсинга через прокси-пул bright data


# first_rows_to_parse = df_filtered.head(1000)
# first_rows_to_parse_filtered = first_rows_to_parse[['url','underground']]
# first_rows_to_parse_filtered
# first_rows_to_parse_filtered.shape
# tqdm.pandas()
# output_file = 'parsed_data.csv'

# #при каждом запуске ячейки будем проверять наличие файла с результатами парсинга
# if os.path.exists(output_file):
#     parsed_df = pd.read_csv(output_file)
#     # Определение уже обработанных URL
#     processed_urls = set(parsed_df['url'])
# else:
#     parsed_df = pd.DataFrame()
#     processed_urls = set()
    
# # processed_df = first_rows_to_parse_filtered.apply(parse_page, axis=1) #получим Series объек как результат выполнения функции apply
# for index, row in tqdm(first_rows_to_parse_filtered.iterrows(), total=first_rows_to_parse_filtered.shape[0]):
#     if row['url'] in processed_urls:
#         continue  # Пропускаем уже обработанные URL
#     parsed_data = parse_page(row) #получим словарь с данными
#     parsed_data['url'] = row['url']  # Добавляем URL в результаты парсинга
#     parsed_df = pd.concat([parsed_df, pd.DataFrame([parsed_data])])
#     # Сохранение промежуточных результатов
#     parsed_df.to_csv(output_file)

# %%
processed_df = pd.read_csv("parsed_data.csv")

# %%
processed_df
# Out:
#              area                                             street  \
# 0       Хамовники                                   Фрунзенская наб.
# 1     Пресненский  Московский международный деловой центр Москва-...
# 2     Пресненский                                      ул. Костикова
# 3     Хорошевский                                   ул. Гризодубовой
# 4        Якиманка                        Лаврушинский жилой комплекс
# ...           ...                                                ...
# 1651          NaN                                                NaN
# 1652          NaN                                                NaN
# 1653          NaN                                                NaN
# 1654          NaN                                                NaN
# 1655          NaN                                                NaN
#
#       mins_to_underground            housing_type  ceiling_height_m  \
# 0                    10.0             Новостройка              34.0
# 1                     4.0  Вторичка / Апартаменты               4.0
# 2                     9.0             Новостройка               3.0
# 3                     7.0                Вторичка               3.0
# 4                     2.0             Новостройка             335.0
# ...                   ...                     ...               ...
# 1651                 16.0                Вторичка               3.0
# 1652                  7.0                Вторичка             264.0
# 1653                  7.0                Вторичка              31.0
# 1654                 11.0                Вторичка               NaN
# 1655                  4.0                Вторичка             304.0
#
#                     bathroom_type             view     renovation_type  \
# 0     3 совмещенных, 1 раздельный          Во двор         Без отделки
# 1     3 совмещенных, 1 раздельный         На улицу        Дизайнерский
# 2     2 совмещенных, 1 раздельный          Во двор  Чистовая с мебелью
# 3                   2 совмещенных  На улицу и двор       Косметический
# 4     3 совмещенных, 1 раздельный          Во двор         Без отделки
# ...                           ...              ...                 ...
# 1651                 1 раздельный              NaN       Косметический
# 1652                 1 раздельный  На улицу и двор          Евроремонт
# 1653                 1 раздельный          Во двор         Без ремонта
# 1654                          NaN              NaN         Без ремонта
# 1655  1 совмещенный, 1 раздельный          Во двор        Дизайнерский
#
#       house_material_type    parking  ...  kitchen_area  construction_year  \
# 0     Монолитно-кирпичный  Подземная  ...          52.7             2027.0
# 1              Монолитный  Подземная  ...           NaN                NaN
# 2              Монолитный        NaN  ...          27.1             2023.0
# 3              Монолитный  Подземная  ...           NaN                NaN
# 4              Монолитный  Подземная  ...          55.0             2024.0
# ...                   ...        ...  ...           ...                ...
# 1651            Панельный        NaN  ...          12.5                NaN
# 1652            Панельный   Наземная  ...          10.0                NaN
# 1653            Кирпичный   Наземная  ...          11.0                NaN
# 1654           Монолитный        NaN  ...          23.0                NaN
# 1655            Кирпичный  Подземная  ...           8.0                NaN
#
#       house_commisioned                finishing_type price_per_meter  \
# 0               Не сдан                   Без отделки       2494802.0
# 1                   NaN                           NaN       1400000.0
# 2                  Сдан  Чистовая, чистовая с мебелью       1470735.0
# 3                   NaN                           NaN        319541.0
# 4               Не сдан                   Без отделки       2809728.0
# ...                 ...                           ...             ...
# 1651                NaN                           NaN        267275.0
# 1652                NaN                           NaN        294118.0
# 1653                NaN                           NaN        389610.0
# 1654                NaN                           NaN        509186.0
# 1655                NaN                           NaN        552632.0
#
#                deal_conditions                                       url  \
# 0     долевое участие (214-ФЗ)  https://www.cian.ru/sale/flat/306341805/
# 1            свободная продажа  https://www.cian.ru/sale/flat/297733877/
# 2            свободная продажа  https://www.cian.ru/sale/flat/306541543/
# 3            свободная продажа  https://www.cian.ru/sale/flat/293126875/
# 4     долевое участие (214-ФЗ)  https://www.cian.ru/sale/flat/303408628/
# ...                        ...                                       ...
# 1651         свободная продажа  https://www.cian.ru/sale/flat/294183025/
# 1652         свободная продажа  https://www.cian.ru/sale/flat/298901367/
# 1653              альтернатива  https://www.cian.ru/sale/flat/300387689/
# 1654         свободная продажа  https://www.cian.ru/sale/flat/308170526/
# 1655         свободная продажа  https://www.cian.ru/sale/flat/307679284/
#
#      mortgage_availability transport_accessibility_score  \
# 0                      NaN                           NaN
# 1                 возможна                           NaN
# 2                      NaN                           8.2
# 3                 возможна                           NaN
# 4                 возможна                           8.7
# ...                    ...                           ...
# 1651              возможна                           NaN
# 1652              возможна                           NaN
# 1653              возможна                           NaN
# 1654                   NaN                           NaN
# 1655              возможна                           NaN
#
#                                                 address
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1651       Москва, ЗАО, р-н Можайский, Вяземская ул., 8
# 1652   Москва, ЮВАО, р-н Люблино, Белореченская ул., 12
# 1653   Москва, ЦАО, р-н Таганский, ул. Земляной Вал, 65
# 1654       Москва, ЗАО, р-н Раменки, Винницкая ул., 8к3
# 1655  Москва, ВАО, р-н Преображенское, Преображенска...
#
# [1656 rows x 21 columns]

# %%
# тут чистили parsed_df от строк, где все значения NaN кроме url
# processed_df = processed_df.dropna(how='all', subset=[col for col in processed_df.columns if col != 'url'])
# processed_df

# %%
# избаавлялись от индексов, которые скопировались при слиянии датафреймов ранее
# processed_df = processed_df.drop(columns=['Unnamed: 0'])
# processed_df.to_csv('./parsed_data.csv',index=False) #сохраняем обработанный датафрейм (без нулевых индексов, нулевых строк)
# processed_df = pd.read_csv("parsed_data.csv")
# processed_df

# %%
# pd.set_option('display.max_colwidth', None)
# # result_df = pd.concat([df, parsed_df], axis=1)  #объединяем по индксу
result_df = pd.merge(df_filtered, processed_df, on='url', how='left') #объединяем полученные детали по столбцу url с исходным датафреймом

# %%
print(result_df.dtypes)
# Out:
# url                               object
# floor                              int64
# floors_count                       int64
# rooms_count                        int64
# total_meters                     float64
# price                            float64
# district                          object
# street_x                          object
# house_number                      object
# underground                       object
# residential_complex               object
# area                              object
# street_y                          object
# mins_to_underground              float64
# housing_type                      object
# ceiling_height_m                 float64
# bathroom_type                     object
# view                              object
# renovation_type                   object
# house_material_type               object
# parking                           object
# living_area                      float64
# kitchen_area                     float64
# construction_year                float64
# house_commisioned                 object
# finishing_type                    object
# price_per_meter                  float64
# deal_conditions                   object
# mortgage_availability             object
# transport_accessibility_score    float64
# address                           object
# dtype: object

# %%
from parse_detailed_cian_page import parse_page

# %%
pd.set_option('display.max_columns', None)
result_df.iloc[1039:] #сохраняем строки, которые еще не были обработаны
# Out:
#                                             url  floor  floors_count  \
# 1039   https://www.cian.ru/sale/flat/295153747/     10            25
# 1040   https://www.cian.ru/sale/flat/307958978/      6            34
# 1041   https://www.cian.ru/sale/flat/308466251/      2            14
# 1042   https://www.cian.ru/sale/flat/307680297/      3            47
# 1043   https://www.cian.ru/sale/flat/307742292/      1             4
# ...                                         ...    ...           ...
# 72758  https://www.cian.ru/sale/flat/304959700/     11            33
# 72759  https://www.cian.ru/sale/flat/307447309/      9            43
# 72760  https://www.cian.ru/sale/flat/306283234/      7            10
# 72761  https://www.cian.ru/sale/flat/304957475/      8            33
# 72762  https://www.cian.ru/sale/flat/306237354/     10            16
#
#        rooms_count  total_meters       price              district  \
# 1039             4          95.3  55500000.0              Аэропорт
# 1040             4          88.6  43582340.0           Обручевский
# 1041             4          87.6   9550000.0               Донской
# 1042             4          89.5         NaN             Печатники
# 1043             4         100.0  12000000.0                   NaN
# ...            ...           ...         ...                   ...
# 72758            1          33.4  10228000.0               Ховрино
# 72759            1          33.5  13300000.0  Покровское-Стрешнево
# 72760            1          33.3   9500000.0                   NaN
# 72761            1          33.2  10065000.0               Ховрино
# 72762            1          33.2   9900000.0        Молжаниновский
#
#                      street_x house_number     underground  \
# 1039   Ленинградский проспект        36с40          Динамо
# 1040                      NaN            3    Воронцовская
# 1041         Варшавское шоссе           16   Верхние котлы
# 1042                      NaN            2     Кожуховская
# 1043                  Садовая           60       Румянцево
# ...                       ...          ...             ...
# 72758               Клинская          2Ак7      Грачёвская
# 72759     Строительный проезд          9С9     Трикотажная
# 72760                     NaN          2.4        Потапово
# 72761               Клинская          2Ак7      Грачёвская
# 72762             Северный ао           к3  Новоподрезково
#
#          residential_complex area street_y  mins_to_underground  \
# 1039          ВТБ Арена парк  NaN      NaN                 10.0
# 1040                 Эвер ЖК  NaN      NaN                  7.0
# 1041                     NaN  NaN      NaN                  6.0
# 1042   Левел Южнопортовая ЖК  NaN      NaN                  9.0
# 1043                     NaN  NaN      NaN                 15.0
# ...                      ...  ...      ...                  ...
# 72758  мой адрес На Клинской  NaN      NaN                  NaN
# 72759             Sky Garden  NaN      NaN                  NaN
# 72760       Дзен-кварталы ЖК  NaN      NaN                  NaN
# 72761  мой адрес На Клинской  NaN      NaN                  NaN
# 72762         Молжаниново ЖК  NaN      NaN                  NaN
#
#                  housing_type  ceiling_height_m  bathroom_type  \
# 1039   Вторичка / Апартаменты              32.0  2 совмещенных
# 1040              Новостройка               3.0            NaN
# 1041   Вторичка / Апартаменты              31.0            NaN
# 1042              Новостройка             285.0  2 совмещенных
# 1043                 Вторичка               NaN  1 совмещенный
# ...                       ...               ...            ...
# 72758                     NaN               NaN            NaN
# 72759                     NaN               NaN            NaN
# 72760                     NaN               NaN            NaN
# 72761                     NaN               NaN            NaN
# 72762                     NaN               NaN            NaN
#
#                   view            renovation_type  house_material_type  \
# 1039   На улицу и двор               Дизайнерский           Монолитный
# 1040               NaN  Без отделки, предчистовая           Монолитный
# 1041          На улицу                 Евроремонт           Сталинский
# 1042           Во двор                Без отделки           Монолитный
# 1043   На улицу и двор              Косметический  Монолитно-кирпичный
# ...                ...                        ...                  ...
# 72758              NaN                        NaN                  NaN
# 72759              NaN                        NaN                  NaN
# 72760              NaN                        NaN                  NaN
# 72761              NaN                        NaN                  NaN
# 72762              NaN                        NaN                  NaN
#
#          parking  living_area  kitchen_area  construction_year  \
# 1039   Подземная          NaN           NaN                NaN
# 1040         NaN         61.9           NaN             2023.0
# 1041    Наземная         70.0          10.0                NaN
# 1042   Подземная         45.9          22.4             2027.0
# 1043    Наземная          NaN          15.0                NaN
# ...          ...          ...           ...                ...
# 72758        NaN          NaN           NaN                NaN
# 72759        NaN          NaN           NaN                NaN
# 72760        NaN          NaN           NaN                NaN
# 72761        NaN          NaN           NaN                NaN
# 72762        NaN          NaN           NaN                NaN
#
#       house_commisioned finishing_type  price_per_meter  \
# 1039                NaN            NaN         582371.0
# 1040               Сдан            NaN         491900.0
# 1041                NaN            NaN         205479.0
# 1042            Не сдан            NaN         497482.0
# 1043                NaN            NaN         110000.0
# ...                 ...            ...              ...
# 72758               NaN            NaN              NaN
# 72759               NaN            NaN              NaN
# 72760               NaN            NaN              NaN
# 72761               NaN            NaN              NaN
# 72762               NaN            NaN              NaN
#
#                 deal_conditions mortgage_availability  \
# 1039          свободная продажа              возможна
# 1040   долевое участие (214-ФЗ)              возможна
# 1041          свободная продажа              возможна
# 1042   долевое участие (214-ФЗ)              возможна
# 1043          свободная продажа              возможна
# ...                         ...                   ...
# 72758                       NaN                   NaN
# 72759                       NaN                   NaN
# 72760                       NaN                   NaN
# 72761                       NaN                   NaN
# 72762                       NaN                   NaN
#
#        transport_accessibility_score  \
# 1039                             NaN
# 1040                             6.1
# 1041                             NaN
# 1042                             NaN
# 1043                             NaN
# ...                              ...
# 72758                            NaN
# 72759                            NaN
# 72760                            NaN
# 72761                            NaN
# 72762                            NaN
#
#                                                  address
# 1039   Москва, САО, р-н Аэропорт, Ленинградский просп...
# 1040   Москва, ЮЗАО, р-н Обручевский, ул. Архитектора...
# 1041                           Москва, Варшавское ш., 16
# 1042        Москва, Левел Южнопортовая жилой комплекс, 2
# 1043   Москва, НАО (Новомосковский), Румянцево деревн...
# ...                                                  ...
# 72758                                                NaN
# 72759                                                NaN
# 72760                                                NaN
# 72761                                                NaN
# 72762                                                NaN
#
# [71724 rows x 31 columns]

# %%
print(df.dtypes)
# Out:
# author                  object
# author_type             object
# url                     object
# location                object
# deal_type               object
# accommodation_type      object
# floor                    int64
# floors_count             int64
# rooms_count              int64
# total_meters           float64
# price                  float64
# district                object
# street                  object
# house_number            object
# underground             object
# residential_complex     object
# dtype: object

# %%
#реализация парсера через selenium
import pandas as pd
import time
from fake_useragent import UserAgent
from tqdm.notebook import tqdm
import os
import random
# import requests
# from bs4 import BeautifulSoup
# from random import randint

output_file = 'parsed_data.csv'
unprocessed_urls = set()
#при каждом запуске ячейки будем проверять наличие файла с результатами парсинга
if os.path.exists(output_file):
    parsed_df = pd.read_csv(output_file)
    # Определение уже обработанных URL
    processed_urls = set(parsed_df['url'])
    print(f"Уже обработанных URL: {len(processed_urls)}")
    unprocessed_urls = set(df_filtered['url'])-processed_urls
    print(f"Осталось обработать URL: {len(unprocessed_urls)}")
else:
    parsed_df = pd.DataFrame()
    processed_urls = set()

urls_input = result_df.iloc[7000:] # потом заменим на unprocessed_urls

user_agent = UserAgent() 
tqdm.pandas()
start_time = time.time()

for index, row in tqdm(urls_input.iterrows(), total=urls_input.shape[0]):
    if row['url'] in processed_urls:
        continue  # Пропускаем уже обработанные URL
    random_choice = random.uniform(2, 5)
    time.sleep(random_choice)
    parsed_detailed_info_data = parse_page(row, user_agent) #получим словарь с данными
    if not parsed_detailed_info_data : #если функция вернула пустой словарь
        print(f"url {row['url']}, Данные не были получены")
        continue #пропускаем
    else:
        parsed_detailed_info_data['url'] = row['url']  # Добавляем URL в результаты парсинга
        print(f"url {row['url']}, {parsed_detailed_info_data}")
        # Преобразование типов данных
        if 'living_area' in parsed_detailed_info_data:
            parsed_detailed_info_data['living_area'] = float(parsed_detailed_info_data['living_area'])
        if 'kitchen_area' in parsed_detailed_info_data:
            parsed_detailed_info_data['kitchen_area'] = float(parsed_detailed_info_data['kitchen_area'])
        if 'price_per_meter' in parsed_detailed_info_data:
            parsed_detailed_info_data['price_per_meter'] = float(parsed_detailed_info_data['price_per_meter'])
        if 'mins_to_underground' in parsed_detailed_info_data:
            parsed_detailed_info_data['mins_to_underground'] = float(parsed_detailed_info_data['mins_to_underground']) if parsed_detailed_info_data['mins_to_underground'] else None
        parsed_detailed_info_data = pd.DataFrame([parsed_detailed_info_data])
        unprocessed_urls.discard(row['url']) #удаляем обработанные строки из списка необработанных
        # Если parsed_df пустой, инициализируем его как parsed_detailed_info_data
        if parsed_df.empty:
            parsed_df = parsed_detailed_info_data.copy()
        elif not parsed_detailed_info_data.empty:
            # Иначе добавляем данные через concat
            parsed_df = pd.concat([parsed_df, parsed_detailed_info_data], ignore_index=True)
        parsed_df.to_csv(output_file, index=False)
        #сохраняем в файл обработанный url и детали квартиры, файл каждый проход цикла будет пополняться новой строкой с деталями квартиры и url
end_time = time.time()
print("Время выполнения цикла:", end_time - start_time, "секунд")
# output_file = 'parsed_data.csv'
# Out:
# Уже обработанных URL: 1679
# Осталось обработать URL: 71027
#   0%|          | 0/65763 [00:00<?, ?it/s]
# Получено Купить трехкомнатную квартиру 76.5м² ул. Ивана Сусанина, 6К3, Москва, САО, р-н Западное Дегунино м.
# found_geo
# url https://www.cian.ru/sale/flat/303133764/, {'address': 'Москва, САО, р-н Западное Дегунино, ул. Ивана Сусанина, 6К3', 'mins_to_underground': '8', 'housing_type': 'Вторичка', 'ceiling_height_m': '274', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Без ремонта', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'kitchen_area': 12.0, 'price_per_meter': '248366', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/303133764/'}
# Получено Продаю трехкомнатную квартиру 77м² ул. Героя России Соломатина, 21, Москва, Завода Мосрентген посело
# Error parsing underground data/ url https://www.cian.ru/sale/flat/306682757/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/306682757/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 77м² ул. Барышиха, 12К1, Москва, м. Митино - база ЦИАН, объявление 30
# Error parsing underground data/ url https://www.cian.ru/sale/flat/305857483/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/305857483/, Данные не были получены
# Получено Купить трехкомнатную квартиру 77м² ул. Новая Дорога, 9, Москва м. Электрозаводская - база ЦИАН, объя
# found_geo
# url https://www.cian.ru/sale/flat/283342083/, {'address': 'Москва, ул. Новая Дорога, 9', 'mins_to_underground': '14', 'housing_type': 'Вторичка', 'ceiling_height_m': '32', 'bathroom_type': '2 совмещенных', 'view': 'Во двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Монолитный', 'parking': 'Подземная', 'living_area': 65.0, 'mortgage_availability': 'возможна', 'price_per_meter': '584416', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/283342083/'}
# Получено Купить трехкомнатную квартиру 76м² ул. Расковой, 23А, Москва, САО, р-н Беговой м. Савёловская - база
# found_geo
# url https://www.cian.ru/sale/flat/292823298/, {'address': 'Москва, САО, р-н Беговой, ул. Расковой, 23А', 'mins_to_underground': '13', 'housing_type': 'Вторичка', 'ceiling_height_m': '3', 'bathroom_type': '1 раздельный', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Кирпичный', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'living_area': 47.0, 'kitchen_area': 6.5, 'price_per_meter': '434211', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/292823298/'}
# Получено Продаю трехкомнатную квартиру 76.4м² ул. Плеханова, 29К1, Москва м. Перово - база ЦИАН, объявление 3
# found_geo
# url https://www.cian.ru/sale/flat/305719493/, {'address': 'Москва, ул. Плеханова, 29К1', 'mins_to_underground': '20', 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'living_area': 47.7, 'kitchen_area': 10.2, 'mortgage_availability': 'возможна', 'price_per_meter': '244110', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/305719493/'}
# Получено Купить трехкомнатную квартиру 76.4м² Лукинская ул., 16, Москва, ЗАО, р-н Ново-Переделкино м. Новопер
# found_geo
# url https://www.cian.ru/sale/flat/304919877/, {'address': 'Москва, ЗАО, р-н Ново-Переделкино, Лукинская ул., 16', 'mins_to_underground': '17', 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'living_area': 45.0, 'kitchen_area': 11.0, 'price_per_meter': '247382', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/304919877/'}
# Получено Продаю трехкомнатную квартиру 77м² ул. Лавриненко, 11к2, Москва, ЮВАО, р-н Некрасовка м. Некрасовка
# found_geo
# url https://www.cian.ru/sale/flat/290061026/, {'address': 'Москва, ЮВАО, р-н Некрасовка, ул. Лавриненко, 11к2', 'mins_to_underground': '17', 'housing_type': 'Вторичка', 'ceiling_height_m': '274', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 44.0, 'kitchen_area': 14.0, 'price_per_meter': '193506', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/290061026/'}
# Получено Продажа трехкомнатной квартиры 77м² Филевский бул., 39, Москва м. Фили - база ЦИАН, объявление 30215
# found_geo
# url https://www.cian.ru/sale/flat/302152441/, {'address': 'Москва, Филевский бул., 39', 'mins_to_underground': None, 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'living_area': 43.0, 'kitchen_area': 10.0, 'mortgage_availability': 'возможна', 'price_per_meter': '297403', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/302152441/'}
# /var/folders/kn/gr9c195971z945gs1b1_xh2r0000gn/T/ipykernel_79133/2495027219.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   parsed_df = pd.concat([parsed_df, parsed_detailed_info_data], ignore_index=True)
# Получено Продажа трехкомнатной квартиры 76м² ул. Василия Петушкова, 15, Москва, СЗАО, р-н Южное Тушино м. Три
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307749637/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307749637/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 76м² ул. Генерала Кузнецова, 18К2, Москва, м. Жулебино - база ЦИАН, об
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307612667/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307612667/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76,2м² пер. Алымов, 4, Москва, м. Преображенская площадь - база ЦИАН,
# Error parsing underground data/ url https://www.cian.ru/sale/flat/302235279/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/302235279/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76.5м² ул. Авиаторов, 5, Москва, ЗАО, р-н Солнцево м. Солнцево - база
# found_geo
# url https://www.cian.ru/sale/flat/307883713/, {'address': 'Москва, ЗАО, р-н Солнцево, ул. Авиаторов, 5', 'mins_to_underground': '15', 'housing_type': 'Вторичка', 'bathroom_type': '1 совмещенный', 'view': 'На улицу и двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Панельный', 'parking': 'Многоуровневая', 'mortgage_availability': '', 'living_area': 52.0, 'kitchen_area': 12.8, 'price_per_meter': '307190', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/307883713/'}
# Получено Продажа трехкомнатной квартиры 76.1м² Челобитьевское ш., 12к2, Москва, СВАО, р-н Северный м. Физтех
# found_geo
# url https://www.cian.ru/sale/flat/307544593/, {'address': 'Москва, СВАО, р-н Северный, Челобитьевское ш., 12к2', 'mins_to_underground': '12', 'housing_type': 'Вторичка', 'ceiling_height_m': '275', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 43.2, 'kitchen_area': 11.0, 'price_per_meter': '262812', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/307544593/'}
# Получено Продаю трехкомнатную квартиру 76.5м² Большая Очаковская ул., 3, Москва м. Аминьевская - база ЦИАН, о
# found_geo
# url https://www.cian.ru/sale/flat/297852245/, {'address': 'Москва, Большая Очаковская ул., 3', 'mins_to_underground': '11', 'housing_type': 'Вторичка', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'living_area': 45.7, 'kitchen_area': 10.4, 'mortgage_availability': 'возможна', 'price_per_meter': '338562', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/297852245/'}
# Получено Купить трехкомнатную квартиру 77м² Ленинский просп., 127, Москва, ЮЗАО, р-н Теплый Стан м. Тропарёво
# found_geo
# url https://www.cian.ru/sale/flat/307548597/, {'address': 'Москва, ЮЗАО, р-н Теплый Стан, Ленинский просп., 127', 'mins_to_underground': '4', 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 раздельный', 'view': 'На улицу', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 45.8, 'kitchen_area': 10.2, 'price_per_meter': '370000', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/307548597/'}
# Получено Купить трехкомнатную квартиру 76.6м² просп. Лихачева, 22, Москва м. Технопарк - база ЦИАН, объявлени
# found_geo
# url https://www.cian.ru/sale/flat/303900885/, {'address': 'Москва, просп. Лихачева, 22', 'mins_to_underground': '14', 'housing_type': 'Вторичка', 'bathroom_type': '2 совмещенных', 'view': 'На улицу и двор', 'renovation_type': 'Без ремонта', 'parking': 'Подземная', 'living_area': 60.0, 'kitchen_area': 12.6, 'mortgage_availability': 'возможна', 'price_per_meter': '385117', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/303900885/'}
# Получено Продаю трехкомнатную квартиру 77м² ул. Госпитальный Вал, 5С1, Москва м. Электрозаводская - база ЦИАН
# found_geo
# url https://www.cian.ru/sale/flat/308254508/, {'address': 'Москва, ул. Госпитальный Вал, 5С1', 'mins_to_underground': '12', 'housing_type': 'Вторичка', 'ceiling_height_m': '275', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'living_area': 47.0, 'kitchen_area': 13.0, 'mortgage_availability': 'возможна', 'price_per_meter': '383104', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/308254508/'}
# Получено Купить трехкомнатную квартиру 77м² ул. Госпитальный Вал, 5С1, Москва, м. Электрозаводская - база ЦИА
# Error parsing underground data/ url https://www.cian.ru/sale/flat/308348796/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/308348796/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76,6м² просп. Вернадского, 10к1, Москва, м. Университет - база ЦИАН, о
# Error parsing underground data/ url https://www.cian.ru/sale/flat/305448894/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/305448894/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 77м² ул. Академика Королева, 8К2, Москва, СВАО, р-н Останкинский м. Ул
# found_geo
# url https://www.cian.ru/sale/flat/308207891/, {'address': 'Москва, СВАО, р-н Останкинский, ул. Академика Королева, 8К2', 'mins_to_underground': '6', 'housing_type': 'Вторичка', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 44.2, 'kitchen_area': 10.4, 'price_per_meter': '376623', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/308207891/'}
# Получено Продаю трехкомнатные апартаменты 76м² ул. Василисы Кожиной, 13, Москва, ЗАО, р-н Филевский парк м. П
# found_geo
# url https://www.cian.ru/sale/flat/305201906/, {'address': 'Москва, ЗАО, р-н Филевский парк, ул. Василисы Кожиной, 13', 'mins_to_underground': '14', 'housing_type': 'Вторичка / Апартаменты', 'bathroom_type': '2 совмещенных', 'view': 'На улицу и двор', 'renovation_type': 'Без ремонта', 'house_material_type': 'Монолитный', 'mortgage_availability': 'возможна', 'living_area': 55.0, 'kitchen_area': 12.0, 'price_per_meter': '438158', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/305201906/'}
# Получено Продажа трехкомнатной квартиры 76м² Шмитовский проезд, 39к9, Москва, м. Шелепиха - база ЦИАН, объявл
# Error parsing underground data/ url https://www.cian.ru/sale/flat/298871188/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/298871188/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76,3м² ул. Генерала Глаголева, 5К1, Москва, м. Бульвар Генерала Карбы
# Error parsing underground data/ url https://www.cian.ru/sale/flat/299030776/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/299030776/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76.8м² Шмитовский проезд, 39к8, Москва, ЦАО, р-н Пресненский м. Москв
# found_geo
# url https://www.cian.ru/sale/flat/302080282/, {'address': 'Москва, ЦАО, р-н Пресненский, Шмитовский проезд, 39к8', 'mins_to_underground': '10', 'housing_type': 'Вторичка', 'ceiling_height_m': '3', 'bathroom_type': '2 совмещенных', 'view': 'На улицу и двор', 'renovation_type': 'Без ремонта', 'house_material_type': 'Монолитный', 'parking': 'Подземная', 'mortgage_availability': '', 'living_area': 40.0, 'kitchen_area': 11.0, 'price_per_meter': '446615', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/302080282/'}
# Получено Купить трехкомнатную квартиру 76м² Гжатская ул., 5к1, Москва, м. Давыдково - база ЦИАН, объявление 3
# Error parsing underground data/ url https://www.cian.ru/sale/flat/302417484/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/302417484/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76,6м² просп. Защитников Москвы, 8, Москва, м. Некрасовка - база ЦИАН
# Error parsing underground data/ url https://www.cian.ru/sale/flat/308360698/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/308360698/, Данные не были получены
# Получено Купить трехкомнатную квартиру 77м² 9-я Северная линия, 25к1, Москва м. Физтех - база ЦИАН, объявлени
# found_geo
# url https://www.cian.ru/sale/flat/284590419/, {'address': 'Москва, 9-я Северная линия, 25к1', 'mins_to_underground': '14', 'housing_type': 'Вторичка', 'ceiling_height_m': '275', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'living_area': 45.5, 'kitchen_area': 13.0, 'mortgage_availability': 'возможна', 'price_per_meter': '223377', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/284590419/'}
# Получено Купить трехкомнатную квартиру 76.5м² Ярославское ш., 34, Москва, СВАО, р-н Ярославский м. ВДНХ - баз
# found_geo
# url https://www.cian.ru/sale/flat/302125005/, {'address': 'Москва, СВАО, р-н Ярославский, Ярославское ш., 34', 'mins_to_underground': None, 'housing_type': 'Вторичка', 'ceiling_height_m': '265', 'bathroom_type': '1 совмещенный', 'view': 'На улицу', 'renovation_type': 'Косметический', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'living_area': 42.3, 'kitchen_area': 9.1, 'price_per_meter': '313725', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/302125005/'}
# /var/folders/kn/gr9c195971z945gs1b1_xh2r0000gn/T/ipykernel_79133/2495027219.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   parsed_df = pd.concat([parsed_df, parsed_detailed_info_data], ignore_index=True)
# Получено Продажа трехкомнатной квартиры 76.4м² Петровско-Разумовский проезд, 24К2, Москва, САО, р-н Савеловск
# found_geo
# url https://www.cian.ru/sale/flat/299988256/, {'address': 'Москва, САО, р-н Савеловский, Петровско-Разумовский проезд, 24К2', 'mins_to_underground': '11', 'housing_type': 'Вторичка', 'ceiling_height_m': '3', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Косметический', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'living_area': 49.0, 'kitchen_area': 9.0, 'price_per_meter': '294503', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/299988256/'}
# Получено Продажа трехкомнатной квартиры 76м² ул. Авиаторов, 6, Москва, м. Солнцево - база ЦИАН, объявление 30
# Error parsing underground data/ url https://www.cian.ru/sale/flat/306676099/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/306676099/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76,4м² проезд 5-й Подбельского, 4АК10, Москва, м. Бульвар Рокоссовско
# Error parsing underground data/ url https://www.cian.ru/sale/flat/302306191/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/302306191/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76м² ул. Васильцовский Стан, 11, Москва м. Кузьминки - база ЦИАН, объ
# found_geo
# url https://www.cian.ru/sale/flat/305857936/, {'address': 'Москва, ул. Васильцовский Стан, 11', 'mins_to_underground': '19', 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 совмещенный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'parking': 'Многоуровневая', 'living_area': 46.0, 'kitchen_area': 10.3, 'mortgage_availability': 'возможна', 'price_per_meter': '271053', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/305857936/'}
# Получено Продажа трехкомнатной квартиры 77м² ул. Лобанова, 4, Москва, ЮАО, р-н Даниловский м. Автозаводская -
# found_geo
# url https://www.cian.ru/sale/flat/306157858/, {'address': 'Москва, ЮАО, р-н Даниловский, ул. Лобанова, 4', 'mins_to_underground': '7', 'housing_type': 'Вторичка', 'ceiling_height_m': '3', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Кирпичный', 'parking': 'Открытая', 'mortgage_availability': 'возможна', 'living_area': 50.0, 'kitchen_area': 9.0, 'price_per_meter': '328571', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/306157858/'}
# Получено Продаю трехкомнатную квартиру 77м² ул. Исаковского, 4К2, Москва, СЗАО, р-н Строгино м. Мякинино - ба
# found_geo
# url https://www.cian.ru/sale/flat/307186613/, {'address': 'Москва, СЗАО, р-н Строгино, ул. Исаковского, 4К2', 'mins_to_underground': '17', 'housing_type': 'Вторичка', 'ceiling_height_m': '27', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 46.0, 'kitchen_area': 10.5, 'price_per_meter': '258442', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/307186613/'}
# Получено Продажа трехкомнатной квартиры 76м² ул. Годовикова, 11к4, Москва м. Алексеевская - база ЦИАН, объявл
# found_geo
# url https://www.cian.ru/sale/flat/304003729/, {'address': 'Москва, ул. Годовикова, 11к4', 'mins_to_underground': '13', 'housing_type': 'Вторичка', 'ceiling_height_m': '31', 'bathroom_type': '1 совмещенный, 1 раздельный', 'view': 'Во двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Монолитный', 'parking': 'Подземная', 'living_area': 41.0, 'kitchen_area': 21.0, 'mortgage_availability': 'возможна', 'price_per_meter': '631579', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/304003729/'}
# Получено Продажа трехкомнатной квартиры 76м² ул. Московская, 3, Москва, Московский, Град Московский микрорайо
# found_geo
# url https://www.cian.ru/sale/flat/305891773/, {'address': 'Москва, Московский, Град Московский микрорайон, ул. Московская, 3', 'mins_to_underground': None, 'housing_type': 'Вторичка', 'ceiling_height_m': '27', 'renovation_type': 'Евроремонт', 'house_material_type': 'Панельный', 'living_area': 53.0, 'kitchen_area': 10.0, 'mortgage_availability': '', 'price_per_meter': '269737', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/305891773/'}
# /var/folders/kn/gr9c195971z945gs1b1_xh2r0000gn/T/ipykernel_79133/2495027219.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   parsed_df = pd.concat([parsed_df, parsed_detailed_info_data], ignore_index=True)
# Получено Продаю трехкомнатную квартиру 77м² ул. Трофимова, 9, Москва м. Автозаводская - база ЦИАН, объявление
# found_geo
# url https://www.cian.ru/sale/flat/308436605/, {'address': 'Москва, ул. Трофимова, 9', 'mins_to_underground': '4', 'housing_type': 'Вторичка', 'house_material_type': 'Кирпичный', 'kitchen_area': 8.0, 'mortgage_availability': 'возможна', 'price_per_meter': '324675', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/308436605/'}
# Получено Купить трехкомнатную квартиру 76.8м² Варшавское ш., 141Ак5, Москва, ЮАО, р-н Чертаново Южное м. Анни
# Error parsing underground data/ url https://www.cian.ru/sale/flat/306816282/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/306816282/, Данные не были получены
# Получено Ошибка - Циан
# Проверяем ваш браузер...Обычно это занимает максимум 5 секунд, иногда до 3 минут.Если
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307318211/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307318211/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76м² ул. Москвитина, 9к2, Москва, НАО (Новомосковский), Московский м.
# found_geo
# url https://www.cian.ru/sale/flat/301447980/, {'address': 'Москва, НАО (Новомосковский), Московский, ул. Москвитина, 9к2', 'mins_to_underground': None, 'housing_type': 'Вторичка', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Монолитный', 'mortgage_availability': '', 'living_area': 45.0, 'kitchen_area': 13.0, 'price_per_meter': '273026', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/301447980/'}
# /var/folders/kn/gr9c195971z945gs1b1_xh2r0000gn/T/ipykernel_79133/2495027219.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   parsed_df = pd.concat([parsed_df, parsed_detailed_info_data], ignore_index=True)
# Получено Продаю трехкомнатную квартиру 77м² Волжский бул., 13, Москва, ЮВАО, р-н Рязанский м. Текстильщики -
# found_geo
# url https://www.cian.ru/sale/flat/307758038/, {'address': 'Москва, ЮВАО, р-н Рязанский, Волжский бул., 13', 'mins_to_underground': '15', 'housing_type': 'Вторичка', 'bathroom_type': '1 совмещенный', 'view': 'Во двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 54.0, 'kitchen_area': 12.0, 'price_per_meter': '277922', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/307758038/'}
# Получено Купить трехкомнатную квартиру 76м² Студенческая ул., 30К1, Москва, ЗАО, р-н Дорогомилово м. Студенче
# found_geo
# url https://www.cian.ru/sale/flat/307261047/, {'address': 'Москва, ЗАО, р-н Дорогомилово, Студенческая ул., 30К1', 'mins_to_underground': '6', 'housing_type': 'Вторичка', 'ceiling_height_m': '32', 'bathroom_type': '2 совмещенных', 'view': 'На улицу и двор', 'renovation_type': 'Дизайнерский', 'mortgage_availability': 'возможна', 'living_area': 55.0, 'kitchen_area': 12.0, 'price_per_meter': '565789', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/307261047/'}
# Получено Купить трехкомнатную квартиру 76,4м² Москва, Кинематографический квартал, Событие жилой комплекс, Со
# Error parsing underground data/ url https://www.cian.ru/sale/flat/308326140/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/308326140/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76.4м² ул. Пырьева, 4К3, Москва, ЗАО, р-н Раменки м. Поклонная - база
# found_geo
# url https://www.cian.ru/sale/flat/307960693/, {'address': 'Москва, ЗАО, р-н Раменки, ул. Пырьева, 4К3', 'mins_to_underground': '18', 'housing_type': 'Вторичка', 'ceiling_height_m': '33', 'bathroom_type': '1 раздельный', 'view': 'На улицу', 'renovation_type': 'Косметический', 'house_material_type': 'Кирпичный', 'mortgage_availability': 'возможна', 'living_area': 49.9, 'kitchen_area': 9.2, 'price_per_meter': '366492', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/307960693/'}
# Получено Продажа трехкомнатной квартиры 76,8м² Шмитовский проезд, 39, Москва, м. Шелепиха - база ЦИАН, объявл
# Error parsing underground data/ url https://www.cian.ru/sale/flat/304236253/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/304236253/, Данные не были получены
# Получено Ошибка 404 - ЦианСтраница не найденаВозможно, у вас опечатка в адресе страницы, или её просто не сущ
# Error parsing underground data/ url https://www.cian.ru/sale/flat/300746758/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/300746758/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76м² 1-я Вольская ул., 16, Москва, м. Люберцы - база ЦИАН, объявление
# Error parsing underground data/ url https://www.cian.ru/sale/flat/297192987/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/297192987/, Данные не были получены
# Получено Продажа трехкомнатных апартаментов 76м² Октябрьская ул., 67, Москва, м. Марьина Роща - база ЦИАН, об
# Error parsing underground data/ url https://www.cian.ru/sale/flat/301574272/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/301574272/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 77м² ул. Исаковского, 4К2, Москва, СЗАО, р-н Строгино м. Мякинино - б
# found_geo
# url https://www.cian.ru/sale/flat/308107108/, {'address': 'Москва, СЗАО, р-н Строгино, ул. Исаковского, 4К2', 'mins_to_underground': '17', 'housing_type': 'Вторичка', 'ceiling_height_m': '27', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 46.0, 'kitchen_area': 10.5, 'price_per_meter': '258442', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/308107108/'}
# Failed to get page https://www.cian.ru/sale/flat/305463586/
# Failed to get page https://www.cian.ru/sale/flat/305463586/
# url https://www.cian.ru/sale/flat/305463586/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 76м² Краснодонская ул., 23К1, Москва, ЮВАО, р-н Люблино м. Люблино - б
# found_geo
# url https://www.cian.ru/sale/flat/306505448/, {'address': 'Москва, ЮВАО, р-н Люблино, Краснодонская ул., 23К1', 'mins_to_underground': '10', 'housing_type': 'Вторичка', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 45.5, 'kitchen_area': 13.0, 'price_per_meter': '289474', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/306505448/'}
# Получено Продажа трехкомнатной квартиры 76м² ул. Годовикова, 11к4, Москва, м. Алексеевская - база ЦИАН, объяв
# Error parsing underground data/ url https://www.cian.ru/sale/flat/304008136/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/304008136/, Данные не были получены
# Failed to get page https://www.cian.ru/sale/flat/303090529/
# Failed to get page https://www.cian.ru/sale/flat/303090529/
# url https://www.cian.ru/sale/flat/303090529/, Данные не были получены
# Получено Купить трехкомнатную квартиру 77м² Боровское ш., 45, Москва, м. Новопеределкино - база ЦИАН, объявле
# Error parsing underground data/ url https://www.cian.ru/sale/flat/298257981/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/298257981/, Данные не были получены
# Получено Купить трехкомнатную квартиру 77м² Покровская ул., 37, Москва, ЮВАО, р-н Некрасовка м. Некрасовка -
# found_geo
# url https://www.cian.ru/sale/flat/291278802/, {'address': 'Москва, ЮВАО, р-н Некрасовка, Покровская ул., 37', 'mins_to_underground': '5', 'housing_type': 'Вторичка', 'ceiling_height_m': '27', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 46.2, 'kitchen_area': 10.1, 'price_per_meter': '214286', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/291278802/'}
# Получено Продаю трехкомнатную квартиру 77м² ул. Семена Гордого, 1, Москва, Ивановское деревня, м. Крёкшино -
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307215581/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307215581/, Данные не были получены
# Failed to get page https://www.cian.ru/sale/flat/297686098/
# Failed to get page https://www.cian.ru/sale/flat/297686098/
# url https://www.cian.ru/sale/flat/297686098/, Данные не были получены
# Failed to get page https://www.cian.ru/sale/flat/297439780/
# Failed to get page https://www.cian.ru/sale/flat/297439780/
# url https://www.cian.ru/sale/flat/297439780/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 77м² Бартеневская ул., 13, Москва м. Бульвар Адмирала Ушакова - база Ц
# Error parsing underground data/ url https://www.cian.ru/sale/flat/306498026/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/306498026/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 76м² просп. Георгиевский, 33к5, Москва, ЗелАО, р-н Крюково, Зеленоград
# found_geo
# url https://www.cian.ru/sale/flat/290620505/, {'address': 'Москва, ЗелАО, р-н Крюково, Зеленоград, мкр. 17-й, просп. Георгиевский, 33к5', 'mins_to_underground': '20', 'housing_type': 'Вторичка', 'ceiling_height_m': '429', 'renovation_type': 'Без ремонта', 'mortgage_availability': 'возможна', 'kitchen_area': 23.0, 'price_per_meter': '231579', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/290620505/'}
# Получено Продажа трехкомнатной квартиры 77м² ул. Перерва, 68/35, Москва, ЮВАО, р-н Марьино м. Люблино - база
# found_geo
# url https://www.cian.ru/sale/flat/304768150/, {'address': 'Москва, ЮВАО, р-н Марьино, ул. Перерва, 68/35', 'mins_to_underground': '15', 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'living_area': 44.3, 'kitchen_area': 10.2, 'price_per_meter': '233766', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/304768150/'}
# Получено Купить трехкомнатную квартиру 76м² Краснополянская ул., 6К1, Москва, м. Ховрино - база ЦИАН, объявле
# Error parsing underground data/ url https://www.cian.ru/sale/flat/301754898/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/301754898/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76.2м² Митинская ул., 26, Москва, СЗАО, р-н Митино м. Митино - база ЦИ
# found_geo
# url https://www.cian.ru/sale/flat/305969415/, {'address': 'Москва, СЗАО, р-н Митино, Митинская ул., 26', 'mins_to_underground': '6', 'housing_type': 'Вторичка', 'ceiling_height_m': '274', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'kitchen_area': 10.0, 'price_per_meter': '246719', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/305969415/'}
# Получено Продажа трехкомнатной квартиры 76.3м² ул. Рудневка, 41, Москва, ВАО, р-н Косино-Ухтомский м. Лухмано
# found_geo
# url https://www.cian.ru/sale/flat/305608510/, {'address': 'Москва, ВАО, р-н Косино-Ухтомский, ул. Рудневка, 41', 'mins_to_underground': '14', 'housing_type': 'Вторичка', 'ceiling_height_m': '27', 'bathroom_type': '1 совмещенный', 'view': 'На улицу и двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Панельный', 'mortgage_availability': 'возможна', 'living_area': 52.1, 'kitchen_area': 12.9, 'price_per_meter': '251638', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/305608510/'}
# Получено Купить трехкомнатную квартиру 76м² Кунцевская ул., 2, Москва, м. Молодёжная - база ЦИАН, объявление
# Error parsing underground data/ url https://www.cian.ru/sale/flat/308380842/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/308380842/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76м² ул. Авиаторов, 6, Москва, м. Солнцево - база ЦИАН, объявление 306
# Error parsing underground data/ url https://www.cian.ru/sale/flat/306666096/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/306666096/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76.9м² Шушенская ул., 4, Москва, СВАО, р-н Лосиноостровский м. Бабушки
# found_geo
# url https://www.cian.ru/sale/flat/302502897/, {'address': 'Москва, СВАО, р-н Лосиноостровский, Шушенская ул., 4', 'mins_to_underground': '22', 'housing_type': 'Вторичка', 'ceiling_height_m': '32', 'bathroom_type': '1 совмещенный', 'view': 'На улицу и двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Кирпичный', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'price_per_meter': '258778', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/302502897/'}
# Получено Купить трехкомнатную квартиру 77м² Юрловский проезд, 27А, Москва м. Бибирево - база ЦИАН, объявление
# found_geo
# url https://www.cian.ru/sale/flat/306368751/, {'address': 'Москва, Юрловский проезд, 27А', 'mins_to_underground': '17', 'housing_type': 'Вторичка', 'ceiling_height_m': '3', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Панельный', 'living_area': 47.0, 'kitchen_area': 10.0, 'mortgage_availability': 'возможна', 'price_per_meter': '263636', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/306368751/'}
# Получено Продажа трехкомнатной квартиры 76,5м² Белореченская ул., 12, Москва, м. Люблино - база ЦИАН, объявле
# Error parsing underground data/ url https://www.cian.ru/sale/flat/299427049/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/299427049/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76,1м² ул. Главмосстроя, 12, Москва, м. Говорово - база ЦИАН, объявле
# Error parsing underground data/ url https://www.cian.ru/sale/flat/300333592/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/300333592/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 77м² ул. Академика Капицы, 6, Москва м. Коньково - база ЦИАН, объявлен
# found_geo
# url https://www.cian.ru/sale/flat/297492650/, {'address': 'Москва, ул. Академика Капицы, 6', 'mins_to_underground': '6', 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'living_area': 51.0, 'kitchen_area': 10.0, 'mortgage_availability': '', 'price_per_meter': '279221', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/297492650/'}
# Получено Купить трехкомнатную квартиру 76.5м² Москва, ЗелАО, р-н Крюково, Зеленоград, мкр. 23-й, 2303 м. Зеле
# found_geo
# url https://www.cian.ru/sale/flat/291180408/, {'address': 'Москва, ЗелАО, р-н Крюково, Зеленоград, мкр. 23-й, 2303', 'mins_to_underground': '23', 'housing_type': 'Вторичка', 'ceiling_height_m': '275', 'bathroom_type': '1 совмещенный', 'view': 'На улицу и двор', 'renovation_type': 'Косметический', 'house_material_type': 'Монолитный', 'parking': 'Подземная', 'mortgage_availability': 'возможна', 'living_area': 43.0, 'price_per_meter': '287582', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/291180408/'}
# Получено Продаю трехкомнатную квартиру 76м² ул. Кондратюка, 2, Москва м. ВДНХ - база ЦИАН, объявление 3022808
# found_geo
# url https://www.cian.ru/sale/flat/302280878/, {'address': 'Москва, ул. Кондратюка, 2', 'mins_to_underground': '3', 'housing_type': 'Вторичка', 'ceiling_height_m': '3', 'bathroom_type': '1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Косметический', 'house_material_type': 'Кирпичный', 'parking': 'Наземная', 'living_area': 52.0, 'kitchen_area': 8.4, 'mortgage_availability': 'возможна', 'price_per_meter': '289474', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/302280878/'}
# Получено Продаю трехкомнатную квартиру 76,1м² аллея Жемчуговой, 5К4, Москва, м. Новогиреево - база ЦИАН, объя
# Error parsing underground data/ url https://www.cian.ru/sale/flat/308001581/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/308001581/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76м² Лукинская ул., 18, Москва м. Новопеределкино - база ЦИАН, объявле
# found_geo
# url https://www.cian.ru/sale/flat/306187902/, {'address': 'Москва, Лукинская ул., 18', 'mins_to_underground': '17', 'housing_type': 'Вторичка', 'ceiling_height_m': '265', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Панельный', 'parking': 'Подземная', 'living_area': 43.2, 'kitchen_area': 10.2, 'mortgage_availability': 'возможна', 'price_per_meter': '279605', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/306187902/'}
# Получено Продажа трехкомнатной квартиры 76.8м² Алтуфьевское ш., 82, Москва м. Алтуфьево - база ЦИАН, объявлен
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307527904/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307527904/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 76м² 1-я Дубровская ул., 13, Москва м. Дубровка - база ЦИАН, объявлени
# found_geo
# url https://www.cian.ru/sale/flat/307314896/, {'address': 'Москва, 1-я Дубровская ул., 13', 'mins_to_underground': '8', 'housing_type': 'Вторичка', 'ceiling_height_m': '3', 'bathroom_type': '1 раздельный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Кирпичный', 'parking': 'Наземная', 'living_area': 52.0, 'kitchen_area': 9.0, 'mortgage_availability': 'возможна', 'price_per_meter': '296053', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/307314896/'}
# Failed to get page https://www.cian.ru/sale/flat/306495598/
# Failed to get page https://www.cian.ru/sale/flat/306495598/
# url https://www.cian.ru/sale/flat/306495598/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76м² ул. Горбунова, 11/3, Москва м. Сетунь - база ЦИАН, объявление 304
# found_geo
# url https://www.cian.ru/sale/flat/304622217/, {'address': 'Москва, ул. Горбунова, 11/3', 'mins_to_underground': '12', 'housing_type': 'Вторичка', 'ceiling_height_m': '27', 'bathroom_type': '1 совмещенный, 1 раздельный', 'view': 'На улицу', 'renovation_type': 'Косметический', 'parking': 'Подземная', 'living_area': 47.0, 'kitchen_area': 10.0, 'mortgage_availability': 'возможна', 'price_per_meter': '301316', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/304622217/'}
# Получено Купить трехкомнатную квартиру 77м² ул. Народного Ополчения, 7К3, Москва, СЗАО, р-н Хорошево-Мневники
# found_geo
# url https://www.cian.ru/sale/flat/300113598/, {'address': 'Москва, СЗАО, р-н Хорошево-Мневники, ул. Народного Ополчения, 7К3', 'mins_to_underground': '12', 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 совмещенный', 'view': 'Во двор', 'renovation_type': 'Косметический', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'living_area': 52.0, 'kitchen_area': 10.0, 'price_per_meter': '298701', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/300113598/'}
# Error parsing https://www.cian.ru/sale/flat/308200515/: Message: timeout: Timed out receiving message from renderer: 28.971
#   (Session info: chrome=130.0.6723.117)
# Stacktrace:
# 0   chromedriver                        0x0000000104a3f634 cxxbridge1$str$ptr + 3645404
# 1   chromedriver                        0x0000000104a37e94 cxxbridge1$str$ptr + 3614780
# 2   chromedriver                        0x00000001044a4104 cxxbridge1$string$len + 88416
# 3   chromedriver                        0x000000010448f704 cxxbridge1$string$len + 3936
# 4   chromedriver                        0x000000010448f48c cxxbridge1$string$len + 3304
# 5   chromedriver                        0x000000010448d83c core::str::slice_error_fail::h1cab30ac4b13c655 + 60316
# 6   chromedriver                        0x000000010448df04 core::str::slice_error_fail::h1cab30ac4b13c655 + 62052
# 7   chromedriver                        0x000000010449b79c cxxbridge1$string$len + 53240
# 8   chromedriver                        0x00000001044ae600 cxxbridge1$string$len + 130652
# 9   chromedriver                        0x000000010448e508 core::str::slice_error_fail::h1cab30ac4b13c655 + 63592
# 10  chromedriver                        0x00000001044ae498 cxxbridge1$string$len + 130292
# 11  chromedriver                        0x000000010451fdb0 cxxbridge1$string$len + 595468
# 12  chromedriver                        0x00000001044daf54 cxxbridge1$string$len + 313264
# 13  chromedriver                        0x00000001044dbba4 cxxbridge1$string$len + 316416
# 14  chromedriver                        0x0000000104a0a1d4 cxxbridge1$str$ptr + 3427196
# 15  chromedriver                        0x0000000104a0d518 cxxbridge1$str$ptr + 3440320
# 16  chromedriver                        0x00000001049f15f8 cxxbridge1$str$ptr + 3325856
# 17  chromedriver                        0x0000000104a0dddc cxxbridge1$str$ptr + 3442564
# 18  chromedriver                        0x00000001049e287c cxxbridge1$str$ptr + 3265060
# 19  chromedriver                        0x0000000104a28884 cxxbridge1$str$ptr + 3551788
# 20  chromedriver                        0x0000000104a28a00 cxxbridge1$str$ptr + 3552168
# 21  chromedriver                        0x0000000104a37b2c cxxbridge1$str$ptr + 3613908
# 22  libsystem_pthread.dylib             0x000000019c9f72e4 _pthread_start + 136
# 23  libsystem_pthread.dylib             0x000000019c9f20fc thread_start + 8
#
# Failed to get page https://www.cian.ru/sale/flat/308200515/
# url https://www.cian.ru/sale/flat/308200515/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 76,3м² Мичуринский просп., 25К1, Москва, м. Раменки - база ЦИАН, объя
# Error parsing underground data/ url https://www.cian.ru/sale/flat/301920637/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/301920637/, Данные не были получены
# Получено Купить трехкомнатную квартиру 76,1м² Белореченская ул., 37К2, Москва, м. Люблино - база ЦИАН, объявл
# Error parsing underground data/ url https://www.cian.ru/sale/flat/302389059/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/302389059/, Данные не были получены
# Error parsing https://www.cian.ru/sale/flat/298230036/: Message: timeout: Timed out receiving message from renderer: -0.010
#   (Session info: chrome=130.0.6723.117)
# Stacktrace:
# 0   chromedriver                        0x0000000100e0f634 cxxbridge1$str$ptr + 3645404
# 1   chromedriver                        0x0000000100e07e94 cxxbridge1$str$ptr + 3614780
# 2   chromedriver                        0x0000000100874104 cxxbridge1$string$len + 88416
# 3   chromedriver                        0x000000010085f704 cxxbridge1$string$len + 3936
# 4   chromedriver                        0x000000010085f48c cxxbridge1$string$len + 3304
# 5   chromedriver                        0x000000010085d83c core::str::slice_error_fail::h1cab30ac4b13c655 + 60316
# 6   chromedriver                        0x000000010085df04 core::str::slice_error_fail::h1cab30ac4b13c655 + 62052
# 7   chromedriver                        0x000000010086b79c cxxbridge1$string$len + 53240
# 8   chromedriver                        0x000000010087e600 cxxbridge1$string$len + 130652
# 9   chromedriver                        0x000000010085e508 core::str::slice_error_fail::h1cab30ac4b13c655 + 63592
# 10  chromedriver                        0x000000010087e498 cxxbridge1$string$len + 130292
# 11  chromedriver                        0x00000001008efb10 cxxbridge1$string$len + 594796
# 12  chromedriver                        0x00000001008aaf54 cxxbridge1$string$len + 313264
# 13  chromedriver                        0x00000001008abba4 cxxbridge1$string$len + 316416
# 14  chromedriver                        0x0000000100dda1d4 cxxbridge1$str$ptr + 3427196
# 15  chromedriver                        0x0000000100ddd518 cxxbridge1$str$ptr + 3440320
# 16  chromedriver                        0x0000000100dc15f8 cxxbridge1$str$ptr + 3325856
# 17  chromedriver                        0x0000000100dddddc cxxbridge1$str$ptr + 3442564
# 18  chromedriver                        0x0000000100db287c cxxbridge1$str$ptr + 3265060
# 19  chromedriver                        0x0000000100df8884 cxxbridge1$str$ptr + 3551788
# 20  chromedriver                        0x0000000100df8a00 cxxbridge1$str$ptr + 3552168
# 21  chromedriver                        0x0000000100e07b2c cxxbridge1$str$ptr + 3613908
# 22  libsystem_pthread.dylib             0x000000019c9f72e4 _pthread_start + 136
# 23  libsystem_pthread.dylib             0x000000019c9f20fc thread_start + 8
#
# Failed to get page https://www.cian.ru/sale/flat/298230036/
# url https://www.cian.ru/sale/flat/298230036/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 76.1м² Аминьевское ш., 4Дк1, Москва, ЗАО, р-н Очаково-Матвеевское м. А
# found_geo
# url https://www.cian.ru/sale/flat/298987535/, {'address': 'Москва, ЗАО, р-н Очаково-Матвеевское, Аминьевское ш., 4Дк1', 'mins_to_underground': '5', 'housing_type': 'Вторичка', 'ceiling_height_m': '27', 'bathroom_type': '1 совмещенный, 1 раздельный', 'view': 'На улицу', 'renovation_type': 'Косметический', 'house_material_type': 'Монолитный', 'mortgage_availability': 'возможна', 'living_area': 45.8, 'kitchen_area': 10.3, 'price_per_meter': '308804', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/298987535/'}
# ...
# found_geo
# url https://www.cian.ru/sale/flat/300348282/, {'address': 'Москва, Митинская ул., 12', 'mins_to_underground': '9', 'housing_type': 'Вторичка', 'ceiling_height_m': '28', 'bathroom_type': '2 совмещенных', 'view': 'Во двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Монолитный', 'parking': 'Подземная', 'living_area': 70.0, 'kitchen_area': 14.0, 'mortgage_availability': 'возможна', 'price_per_meter': '290000', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/300348282/'}
# Получено Ошибка - Циан
# Проверяем ваш браузер...Обычно это занимает максимум 5 секунд, иногда до 3 минут.Если
# Error parsing underground data/ url https://www.cian.ru/sale/flat/283955759/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/283955759/, Данные не были получены
# Получено Купить трехкомнатную квартиру 102,4м² к1.2, Москва, Шагал жилой комплекс, 2-я очередь, м. ЗИЛ - база
# Error parsing underground data/ url https://www.cian.ru/sale/flat/306036339/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/306036339/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 103м² Можайское ш., 22к1, Москва, м. Рабочий посёлок - база ЦИАН, объя
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307302008/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307302008/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 101м² Ломоносовский просп., 36, Москва, м. Ломоносовский проспект - б
# Error parsing underground data/ url https://www.cian.ru/sale/flat/291367315/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/291367315/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 101,9м² Нижегородская ул., 84к1, Москва, м. Нижегородская - база ЦИАН,
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307965518/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307965518/, Данные не были получены
# Получено Купить трехкомнатную квартиру 103,2м² Варшавское ш., 94, Москва, м. Варшавская - база ЦИАН, объявлен
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307435629/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307435629/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 105м² Озерная ул., 35, Москва, м. Озёрная - база ЦИАН, объявление 3038
# Error parsing underground data/ url https://www.cian.ru/sale/flat/303866459/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/303866459/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 102.7м² Первомайская ул., 42к3, Москва м. Измайловская - база ЦИАН, о
# found_geo
# url https://www.cian.ru/sale/flat/308458399/, {'address': 'Москва, Первомайская ул., 42к3', 'mins_to_underground': '9', 'housing_type': 'Вторичка', 'bathroom_type': '2 совмещенных', 'view': 'На улицу и двор', 'renovation_type': 'Дизайнерский', 'parking': 'Наземная', 'kitchen_area': 20.0, 'mortgage_availability': 'возможна', 'price_per_meter': '427264', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/308458399/'}
# Получено Продажа трехкомнатной квартиры 100.2м² ул. Лобачевского, 120к1, Москва, ЗАО, р-н Раменки м. Аминьевс
# found_geo
# url https://www.cian.ru/sale/flat/307532296/, {'address': 'Москва, ЗАО, р-н Раменки, ул. Лобачевского, 120к1', 'mins_to_underground': '8', 'housing_type': 'Вторичка', 'ceiling_height_m': '31', 'renovation_type': 'Дизайнерский', 'parking': 'Подземная', 'mortgage_availability': 'возможна', 'kitchen_area': 54.0, 'price_per_meter': '607784', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/307532296/'}
# Получено Купить трехкомнатную квартиру 103.3м² Новочеремушкинская ул., 17, Москва, ЮЗАО, р-н Академический м.
# found_geo
# url https://www.cian.ru/sale/flat/305908215/, {'address': 'Москва, ЮЗАО, р-н Академический, Новочеремушкинская ул., 17', 'mins_to_underground': '11', 'housing_type': 'Вторичка', 'ceiling_height_m': '31', 'bathroom_type': '2 совмещенных, 1 раздельный', 'view': 'Во двор', 'renovation_type': 'Дизайнерский', 'house_material_type': 'Монолитный', 'mortgage_availability': 'возможна', 'living_area': 48.5, 'kitchen_area': 22.6, 'price_per_meter': '716360', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/305908215/'}
# Получено Продаю трехкомнатную квартиру 100м² ул. Николинские Ключи, 32, Москва, Ивановское деревня м. Саларье
# found_geo
# url https://www.cian.ru/sale/flat/258735887/, {'address': 'Москва, Ивановское деревня, ул. Николинские Ключи, 32', 'mins_to_underground': None, 'housing_type': 'Вторичка', 'bathroom_type': '1 совмещенный, 1 раздельный', 'view': 'Во двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Монолитный', 'parking': 'Наземная', 'living_area': 65.0, 'kitchen_area': 18.0, 'mortgage_availability': 'возможна', 'price_per_meter': '140000', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/258735887/'}
# /var/folders/kn/gr9c195971z945gs1b1_xh2r0000gn/T/ipykernel_79133/2495027219.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   parsed_df = pd.concat([parsed_df, parsed_detailed_info_data], ignore_index=True)
# Получено Продажа трехкомнатной квартиры 101,6м² ул. Академика Волгина, 2С1, Москва, м. Университет Дружбы Нар
# Error parsing underground data/ url https://www.cian.ru/sale/flat/299890393/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/299890393/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 104м² ул. Космонавта Волкова, 29К1, Москва, м. Красный Балтиец - база
# Error parsing underground data/ url https://www.cian.ru/sale/flat/308405459/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/308405459/, Данные не были получены
# Получено Купить трехкомнатную квартиру 102.6м² ул. Авиаконструктора Петлякова, 29, Москва, НАО (Новомосковски
# found_geo
# url https://www.cian.ru/sale/flat/301138047/, {'address': 'Москва, НАО (Новомосковский), Внуковское поселение, ул. Авиаконструктора Петлякова, 29', 'mins_to_underground': '14', 'housing_type': 'Вторичка', 'ceiling_height_m': '264', 'bathroom_type': '1 совмещенный, 1 раздельный', 'view': 'На улицу и двор', 'renovation_type': 'Евроремонт', 'house_material_type': 'Панельный', 'parking': 'Наземная', 'mortgage_availability': 'возможна', 'living_area': 59.8, 'kitchen_area': 10.6, 'price_per_meter': '243665', 'deal_conditions': 'альтернатива', 'url': 'https://www.cian.ru/sale/flat/301138047/'}
# Получено Продажа трехкомнатной квартиры 101,7м² ул. Ясеневая, 5к1, Москва, Сосенки деревня, м. Ольховая - баз
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307136269/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307136269/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 100.7м² Ленинградский просп., 37/3, Москва м. Аэропорт - база ЦИАН, об
# found_geo
# url https://www.cian.ru/sale/flat/307811234/, {'address': 'Москва, Ленинградский просп., 37/3', 'mins_to_underground': '13', 'housing_type': 'Вторичка', 'bathroom_type': '2 совмещенных', 'view': 'На улицу и двор', 'renovation_type': 'Без ремонта', 'living_area': 75.0, 'kitchen_area': 7.0, 'mortgage_availability': '', 'price_per_meter': '575968', 'deal_conditions': 'свободная продажа', 'url': 'https://www.cian.ru/sale/flat/307811234/'}
# Получено Купить трехкомнатную квартиру 102,8м² ул. Обручева, 23к3, Москва, м. Воронцовская - база ЦИАН, объяв
# Error parsing underground data/ url https://www.cian.ru/sale/flat/306278601/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/306278601/, Данные не были получены
# Получено Купить трехкомнатную квартиру 103,9м² Сиреневый бул., 62К1, Москва, м. Первомайская - база ЦИАН, объ
# Error parsing underground data/ url https://www.cian.ru/sale/flat/301127526/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/301127526/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 104м² Погонный проезд, 3ак6, Москва, м. Белокаменная - база ЦИАН, объя
# Error parsing underground data/ url https://www.cian.ru/sale/flat/305151119/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/305151119/, Данные не были получены
# Получено Купить трехкомнатные апартаменты 100,7м² Флотская ул., 7к3, Москва, м. Речной вокзал - база ЦИАН, об
# Error parsing underground data/ url https://www.cian.ru/sale/flat/302776209/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/302776209/, Данные не были получены
# Получено Продаю трехкомнатную квартиру 104.4м² проезд Невельского, 6к3, Москва, ЮВАО, р-н Лефортово м. Авиамо
# Error parsing underground data/ url https://www.cian.ru/sale/flat/307875344/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/307875344/, Данные не были получены
# Получено Продажа трехкомнатной квартиры 101.5м² Часовая ул., Москва, САО, р-н Аэропорт м. Сокол - база ЦИАН,
# found_geo
# url https://www.cian.ru/sale/flat/293847289/, {'address': 'Москва, САО, р-н Аэропорт, Часовая ул.', 'mins_to_underground': '9', 'housing_type': 'Новостройка', 'bathroom_type': '2 совмещенных', 'house_material_type': 'Монолитный', 'parking': 'Подземная', 'living_area': 44.3, 'kitchen_area': 23.3, 'construction_year': 2025, 'house_commisioned': 'Не сдан', 'renovation_type': 'Чистовая', 'price_per_meter': '393596', 'deal_conditions': 'переуступка', 'mortgage_availability': 'возможна', 'url': 'https://www.cian.ru/sale/flat/293847289/'}
# Получено Продаю трехкомнатную квартиру 105м² Дегтярный пер., 15к2, Москва, м. Пушкинская - база ЦИАН, объявле
# Error parsing underground data/ url https://www.cian.ru/sale/flat/291484598/: cannot access local variable 'found_geo' where it is not associated with a value
# url https://www.cian.ru/sale/flat/291484598/, Данные не были получены
# Failed to get page https://www.cian.ru/sale/flat/304416535/
# Failed to get page https://www.cian.ru/sale/flat/304416535/
# url https://www.cian.ru/sale/flat/304416535/, Данные не были получены
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[15], line 36
#      34 random_choice = random.uniform(2, 5)
#      35 time.sleep(random_choice)
# ---> 36 parsed_detailed_info_data = parse_page(row, user_agent) #получим словарь с данными
#      37 if not parsed_detailed_info_data : #если функция вернула пустой словарь
#      38     print(f"url {row['url']}, Данные не были получены")
#
# File ~/Documents/Мага ИИ/Годовой проект/team18_yp_realestate_price_forecast_v1/parse_detailed_cian_page.py:121, in parse_page(row, user_agent)
#     119     df_input_underground = row['underground'] # извлекаем метро, ниже будем сравнивать с тем, что нашли на странице
#     120 #html_text = proxy_request(url) #получаем html страницы через запрос в пул прокси-серверов
# --> 121 html_text = selenium_request(url, user_agent) #получаем html страницы через selenium
#     122 if not html_text or html_text == None:
#     123     print(f"Failed to get page {url}")
#
# File ~/Documents/Мага ИИ/Годовой проект/team18_yp_realestate_price_forecast_v1/parse_detailed_cian_page.py:82, in selenium_request(url, user_agent)
#      80     print(f"Error parsing {url}: {e}")
#      81     return None
# ---> 82 html_code = driver.page_source
#      83 if not html_code:
#      84     print(f"Failed to get page {url}")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:455, in WebDriver.page_source(self)
#     446 @property
#     447 def page_source(self) -> str:
#     448     """Gets the source of the current page.
#     449
#     450     :Usage:
#    (...)
#     453             driver.page_source
#     454     """
# --> 455     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 30.000
#   (Session info: chrome=130.0.6723.117)
# Stacktrace:
# 0   chromedriver                        0x000000010543b634 cxxbridge1$str$ptr + 3645404
# 1   chromedriver                        0x0000000105433e94 cxxbridge1$str$ptr + 3614780
# 2   chromedriver                        0x0000000104ea0104 cxxbridge1$string$len + 88416
# 3   chromedriver                        0x0000000104e8b704 cxxbridge1$string$len + 3936
# 4   chromedriver                        0x0000000104e8b48c cxxbridge1$string$len + 3304
# 5   chromedriver                        0x0000000104e8983c core::str::slice_error_fail::h1cab30ac4b13c655 + 60316
# 6   chromedriver                        0x0000000104e89f04 core::str::slice_error_fail::h1cab30ac4b13c655 + 62052
# 7   chromedriver                        0x0000000104e9779c cxxbridge1$string$len + 53240
# 8   chromedriver                        0x0000000104eaa600 cxxbridge1$string$len + 130652
# 9   chromedriver                        0x0000000104e8a508 core::str::slice_error_fail::h1cab30ac4b13c655 + 63592
# 10  chromedriver                        0x0000000104eaa498 cxxbridge1$string$len + 130292
# 11  chromedriver                        0x0000000104f1bdb0 cxxbridge1$string$len + 595468
# 12  chromedriver                        0x0000000104ed6f54 cxxbridge1$string$len + 313264
# 13  chromedriver                        0x0000000104ed7ba4 cxxbridge1$string$len + 316416
# 14  chromedriver                        0x00000001054061d4 cxxbridge1$str$ptr + 3427196
# 15  chromedriver                        0x0000000105409518 cxxbridge1$str$ptr + 3440320
# 16  chromedriver                        0x00000001053ed5f8 cxxbridge1$str$ptr + 3325856
# 17  chromedriver                        0x0000000105409ddc cxxbridge1$str$ptr + 3442564
# 18  chromedriver                        0x00000001053de87c cxxbridge1$str$ptr + 3265060
# 19  chromedriver                        0x0000000105424884 cxxbridge1$str$ptr + 3551788
# 20  chromedriver                        0x0000000105424a00 cxxbridge1$str$ptr + 3552168
# 21  chromedriver                        0x0000000105433b2c cxxbridge1$str$ptr + 3613908
# 22  libsystem_pthread.dylib             0x000000019c9f72e4 _pthread_start + 136
# 23  libsystem_pthread.dylib             0x000000019c9f20fc thread_start + 8

# %%
parsed_df = pd.read_csv('parsed_data.csv')
result_df = pd.merge(df_filtered, parsed_df, on='url', how='left') #обновляем датафрейм с деталями
#ушел от идеи обновлять в цикле, тк выбрасывается ошибка с суфиксами, поэтому просто объединяю датафреймы после сохранения в файл
result_df.iloc[647:657]

# %%
# result_df[result_df['url']=='https://www.cian.ru/sale/flat/279704136/']
result_df[result_df['url']=='https://www.cian.ru/sale/flat/297405165/']

# %%
result_df[result_df['kitchen_area_y'].notna()]

# %%
pd.set_option('display.max_columns', None)
result_df.iloc[625:635]

# %%
view_data = pd.read_csv('./parsed_data_selenium_test.csv')
view_data
# parsed_df

# %%
view_data

# %%
df = pd.read_csv('./united_filtered.csv', sep=';')
df[df['price'].isna()]

# %%
parsed_df = pd.read_csv('./parsed_data.csv', sep=',')
parsed_df_filtered = parsed_df.drop(['url','Unnamed: 0'],axis=1)
print(len(parsed_df_filtered)-len(parsed_df_filtered[parsed_df_filtered.isna().all(axis=1)]))

# %%
parsed_df

# %%
# from bs4 import BeautifulSoup
# text = '<div data-name="Geo"><span itemprop="name" content="Москва, ЦАО, р-н Хамовники, Фрунзенская наб., 30"></span><address><div class="a10a3f92e9--address-line--GRDTb"><div data-name="AddressContainer"><a data-name="AddressItem" class="a10a3f92e9--address--SMU25" href="https://www.cian.ru/cat.php?deal_type=sale&amp;engine_version=2&amp;object_type%5B0%5D=2&amp;offer_type=flat&amp;region=1&amp;room4=1">Москва</a>, <a data-name="AddressItem" class="a10a3f92e9--address--SMU25" href="https://www.cian.ru/kupit-4-komnatnuyu-kvartiru-novostroyki-moskva-cao-044/">ЦАО</a>, <a data-name="AddressItem" class="a10a3f92e9--address--SMU25" href="https://www.cian.ru/kupit-4-komnatnuyu-kvartiru-novostroyki-moskva-hamovniki-0421/">р-н Хамовники</a>, <a data-name="AddressItem" class="a10a3f92e9--address--SMU25" href="https://www.cian.ru/kupit-4-komnatnuyu-kvartiru-novostroyki-moskva-frunzenskaya-naberezhnaya-022342/">Фрунзенская наб.</a>, <a data-name="AddressItem" class="a10a3f92e9--address--SMU25" href="https://www.cian.ru/cat.php?deal_type=sale&amp;engine_version=2&amp;house%5B0%5D=88670&amp;object_type%5B0%5D=2&amp;offer_type=flat&amp;room4=1">30</a><span data-name="MapAnchor" class="a10a3f92e9--anchor--XqEHi">На карте</span></div></div><ul data-name="UndergroundList" class="a10a3f92e9--undergrounds--sGE99"><li data-name="UndergroundItem" class="a10a3f92e9--underground--pjGNr"><div class="a10a3f92e9--icon--mVzev"><span data-name="UndergroundIcon" class="a10a3f92e9--icon--cJCta" style="color:#CF0000"><svg class="a10a3f92e9--container--izJBY a10a3f92e9--display_inline-block--xc1D8 a10a3f92e9--color_current_color--KRvSV a10a3f92e9--color_current_color--MqB6f" aria-hidden="true" width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M0 12.155v1.472h5.556v-1.472h-.89L5.557 9 8 12.155 10.444 9l.89 3.154h-.89v1.472H16v-1.472h-.889l-4-9.884L8 8.37l-3.111-6.1-4 9.884H0Z" fill="currentColor"></path></svg></span></div><a class="a10a3f92e9--underground_link--VnUVj" href="https://www.cian.ru/kupit-4-komnatnuyu-kvartiru-novostroyki-moskva-metro-frunzenskaya/" target="_blank" rel="noreferrer">Фрунзенская</a><span class="a10a3f92e9--underground_time--YvrcI"><div class="a10a3f92e9--icon--mVzev"><svg class="a10a3f92e9--container--izJBY a10a3f92e9--display_inline-block--xc1D8 a10a3f92e9--color_icon-secondary-default--Pnd5e" aria-hidden="true" width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><g fill="currentColor"><path d="M8.67 4.471c.966 0 1.75-.778 1.75-1.738S9.636.993 8.67.993c-.967 0-1.75.78-1.75 1.74A1.74 1.74 0 0 0 8.142 4.39L3.743 5.68 2.605 8.65l1.868.715.783-2.045 1.12-.328L3.449 15h2.13l.094-.259-.017-.006 2.557-6.937.258-.707L9.662 8H13V6h-2.662L8.275 4.427c.127.03.26.044.395.044Z"></path><path d="M11 15H9v-3.586l-.771-.77.762-2.068 2.01 2.01V15Z"></path></g></svg></div>10 мин.</span></li><li data-name="UndergroundItem" class="a10a3f92e9--underground--pjGNr"><div class="a10a3f92e9--icon--mVzev"><span data-name="UndergroundIcon" class="a10a3f92e9--icon--cJCta" style="color:#800000"><svg class="a10a3f92e9--container--izJBY a10a3f92e9--display_inline-block--xc1D8 a10a3f92e9--color_current_color--KRvSV a10a3f92e9--color_current_color--MqB6f" aria-hidden="true" width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M0 12.155v1.472h5.556v-1.472h-.89L5.557 9 8 12.155 10.444 9l.89 3.154h-.89v1.472H16v-1.472h-.889l-4-9.884L8 8.37l-3.111-6.1-4 9.884H0Z" fill="currentColor"></path></svg></span></div><a class="a10a3f92e9--underground_link--VnUVj" href="https://www.cian.ru/kupit-4-komnatnuyu-kvartiru-novostroyki-moskva-metro-park-kultury/" target="_blank" rel="noreferrer">Парк Культуры</a><span class="a10a3f92e9--underground_time--YvrcI"><div class="a10a3f92e9--icon--mVzev"><svg class="a10a3f92e9--container--izJBY a10a3f92e9--display_inline-block--xc1D8 a10a3f92e9--color_icon-secondary-default--Pnd5e" aria-hidden="true" width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><g fill="currentColor"><path d="M8.67 4.471c.966 0 1.75-.778 1.75-1.738S9.636.993 8.67.993c-.967 0-1.75.78-1.75 1.74A1.74 1.74 0 0 0 8.142 4.39L3.743 5.68 2.605 8.65l1.868.715.783-2.045 1.12-.328L3.449 15h2.13l.094-.259-.017-.006 2.557-6.937.258-.707L9.662 8H13V6h-2.662L8.275 4.427c.127.03.26.044.395.044Z"></path><path d="M11 15H9v-3.586l-.771-.77.762-2.068 2.01 2.01V15Z"></path></g></svg></div>21 мин.</span></li><li data-name="UndergroundItem" class="a10a3f92e9--underground--pjGNr"><div class="a10a3f92e9--icon--mVzev"><span data-name="UndergroundIcon" class="a10a3f92e9--icon--cJCta" style="color:#03238B"><svg class="a10a3f92e9--container--izJBY a10a3f92e9--display_inline-block--xc1D8 a10a3f92e9--color_current_color--KRvSV a10a3f92e9--color_current_color--MqB6f" aria-hidden="true" width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M0 12.155v1.472h5.556v-1.472h-.89L5.557 9 8 12.155 10.444 9l.89 3.154h-.89v1.472H16v-1.472h-.889l-4-9.884L8 8.37l-3.111-6.1-4 9.884H0Z" fill="currentColor"></path></svg></span></div><a class="a10a3f92e9--underground_link--VnUVj" href="https://www.cian.ru/kupit-4-komnatnuyu-kvartiru-novostroyki-moskva-metro-smolenskaya/" target="_blank" rel="noreferrer">Смоленская</a><span class="a10a3f92e9--underground_time--YvrcI"><div class="a10a3f92e9--icon--mVzev"><svg class="a10a3f92e9--container--izJBY a10a3f92e9--display_inline-block--xc1D8 a10a3f92e9--color_icon-secondary-default--Pnd5e" aria-hidden="true" width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="m14 7-.84-4.196A1 1 0 0 0 12.18 2H3.82a1 1 0 0 0-.98.804L2 7 1 8v4a1 1 0 0 0 1 1v1a1 1 0 0 0 1 1h1a1 1 0 0 0 1-1v-1h6v1a1 1 0 0 0 1 1h1a1 1 0 0 0 1-1v-1a1 1 0 0 0 1-1V8l-1-1Zm-2.64-3H4.64L4 7h8l-.64-3ZM3 10a1 1 0 1 1 2 0 1 1 0 0 1-2 0Zm9-1a1 1 0 1 0 0 2 1 1 0 0 0 0-2Z" fill="currentColor"></path></svg></div>7 мин.</span></li></ul><ul data-name="HighwayList" class="a10a3f92e9--highways--CfZhE"></ul></address></div>'

# # Создаем объект BeautifulSoup
# soup = BeautifulSoup(text, 'html.parser')

# # Применяем метод prettify для красивого вывода HTML
# formatted_html = soup.prettify()

# # Выводим результат
# with open('output.txt', 'w', encoding='utf-8') as file:
#     file.write(formatted_html)

# %%
# page_data = {}

# found_geo = soup.find('div',{'data-name':'Geo'})
# if found_geo:
#     print("found_geo")
# else:
#     print("Geo element not found.")
# address_tag = found_geo.find('span', {'itemprop': 'name'})
# page_data['address'] = address_tag['content'] if address_tag else None
# print(page_data['address'])

# #находим список тегов метро и формируем список из названий
# underground_tags = found_geo.find('ul', {'data-name':'UndergroundList'}).find_all('a',{'class':'a10a3f92e9--underground_link--VnUVj'}) 
# underground_list = []
# for item in underground_tags:
#     if item.parent.find('path',{'d': lambda x: x and x.startswith('M8.67')}):
#         pedestrian_icon = item.parent.find('path',{'d': lambda x: x and x.startswith('M8.67')})
#         print(pedestrian_icon)
#         #если иконка пешком
#         if pedestrian_icon: 
#             print("Пешком")
#             underground_list.append(item.text)
#         print(item.text)
#         print(item.parent.find('span',{'class':'a10a3f92e9--underground_time--YvrcI'}).text) #мин до метро
    
    
# print(f'Пшеком до следующих станций: {underground_list}')
